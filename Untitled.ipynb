# %%
# Pothole Detection using YOLOv8
# !pip install ultralytics opencv-python

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
# Training was already performed earlier.
# This cell shows the training configuration.
model = YOLO("yolov8n.pt")

# model.train(
#     data="data.yaml",
#     epochs=50,
#     imgsz=640
# )

# %%
model = YOLO("runs/segment/train-2/weights/best.pt")

# %%
img = cv2.imread("runs/segment/predict/result.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(639.5), np.float64(-0.5))

# %%
img = cv2.imread("runs/segment/predict/result2.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(639.5), np.float64(-0.5))

# %%
img = cv2.imread("runs/segment/predict/result4.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(639.5), np.float64(-0.5))
